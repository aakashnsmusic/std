# %%
a = [115.3,195.5,120.5,11.2,90.4,105.6,110.9,116.3,122.3,125.4,122.3]
avg = sum(a) / len(a)
print("Mean: ", avg)
l = len(a)
a.sort()
n=len(a)
n=len(a)
if n%2==2:
    median=(a[int(n/2)-1]+a[int(n/2)])/2
else:
    median=a[(int(n/2))]
print(median)

count = {}
m = 0
for i in range(0,len(l1)):
    if a[i] not in count:
        count[a[i]] = 1
        else:
            count[a[i]] += 1
            if m < count[a[i]]:
                m = count[a[i]]
                mode = a[i]
print(mode)
y = []
for i in range(0,len(a)):
    y.append((a[i] - avg) ** 2)
var = sum(y) / len(a)
sd = (var) ** (1/2)
print("Variance: ", var)
print("Standard Deviation: ", sd)
#min max normalisation
mi = min(a)
ma = max(a)
z = []
for i in range(0,len(a)):
    z.append( ( (a[i] - mi) / (ma - mi) ) )
print("Normalized List: ", z)
#standardisation
z = []
for i in range(0,len(a)):
    z.append( ( (a[i] - avg) / (sd) ) )
print("Normalized List: ", z)
from sklearn.preprocessing import StandardScaler,Normalizer
transformer=Normalizer().fit(X)
scaler=StandardScaler(x)
